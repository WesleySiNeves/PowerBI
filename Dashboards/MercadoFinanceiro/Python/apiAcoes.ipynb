# %% [markdown]
# Importando is pacotes necessários

# %%
from chaveApi import chave_Api
import requests
import pandas as pd
from Io

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=RAIZ4.SAO&apikey={chave_Api}&data_type=csv'

r = requests.get(url)

r.json()
# Out:
# {'Meta Data': {'1. Information': 'Weekly Adjusted Prices and Volumes',
#   '2. Symbol': 'RAIZ4.SAO',
#   '3. Last Refreshed': '2023-06-07',
#   '4. Time Zone': 'US/Eastern'},
#  'Weekly Adjusted Time Series': {'2023-06-07': {'1. open': '3.6900',
#    '2. high': '4.0500',
#    '3. low': '3.6800',
#    '4. close': '3.9500',
#    '5. adjusted close': '3.9500',
#    '6. volume': '51955200',
#    '7. dividend amount': '0.0000'},
#   '2023-06-02': {'1. open': '3.4900',
#    '2. high': '3.8500',
#    '3. low': '3.4600',
#    '4. close': '3.7100',
#    '5. adjusted close': '3.7100',
#    '6. volume': '114273800',
#    '7. dividend amount': '0.0000'},
#   '2023-05-26': {'1. open': '3.7300',
#    '2. high': '3.7600',
#    '3. low': '3.3400',
#    '4. close': '3.4600',
#    '5. adjusted close': '3.4600',
#    '6. volume': '123282600',
#    '7. dividend amount': '0.0000'},
#   '2023-05-19': {'1. open': '3.3500',
#    '2. high': '3.7000',
#    '3. low': '3.0500',
#    '4. close': '3.6700',
# ...

# %%
from pandas.io.json import json_normalize

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=RAIZ4.SAO&apikey={chave_Api}&data_type=csv'

r = requests.get(url)

pd.read_csv(r.text)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35972\3252217252.py in <module>
#       6 r = requests.get(url)
#       7
# ----> 8 pd.read_csv(r.text)
#
# c:\Users\Wesley.Neves\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
